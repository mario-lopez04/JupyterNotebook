# %% [markdown]
# #Mi primer notebook
#
# primera prueba de *jupyter notebook*
# ![Imagen](data:image/jpeg;base64,...)

# %%
print("Auxilio, me desmayo, callese viejo lesbiano!!")

# %%
print ("bloque 2")
